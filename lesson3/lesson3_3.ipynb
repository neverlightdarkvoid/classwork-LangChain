# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        }
        
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T07:53:16.8352169Z', 'response': '想像一下 Python 的函式就像是**工具箱**，裡面有各種各樣的工具，你可以用它們來做不同的事情。\n\n**簡單來說，Python 的函式就是：**\n\n1. **定義一個任務：** 你想做什麼？例如，計算一個數字、讀取一個文件、顯示一個文本等等。\n2. **寫一個指令：** 函式會寫一個小小的指令，告訴 Python 該怎麼做。\n3. **執行指令：** 程式會執行這個指令，並在輸出結果中顯示出來。\n\n**舉個例子：**\n\n假設你想讓 Python 算出 2 + 2：\n\n```python\nresult = 2 + 2\nprint(result)  # 輸出: 4\n```\n\n這段程式碼寫了一個函式，它會算出 2 + 2 的結果，並將結果輸出到螢幕上。\n\n**重點：**\n\n* **函式是可重複使用的：** 你可以多次使用相同的函式，不用重新寫程式碼。\n* **函式可以接受參數：** 像是輸入資料，讓函式知道需要什麼。\n* **函式可以輸出結果：** 函式會把結果顯示出來，讓你看見。\n\n**總結：** 函式就像是程式碼的「小片段」，執行特定任務，讓程式能完成目標。\n\n希望這個解釋能讓你理解 Python 的函式是什麼！\n', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 239230, 237105, 74624, 48280, 185411, 26549, 237026, 32651, 236918, 238780, 237522, 237536, 106, 107, 105, 4368, 107, 103146, 19757, 17856, 10363, 238780, 237522, 55326, 237026, 1018, 30398, 239346, 1018, 236900, 83633, 237078, 77722, 237977, 239022, 236918, 30398, 236900, 71407, 237105, 162576, 237967, 237893, 35078, 25606, 236924, 108, 1018, 74624, 94757, 236900, 32651, 10363, 238780, 237522, 7888, 237184, 1018, 108, 236770, 236761, 5213, 67189, 19966, 152807, 237184, 1018, 43758, 237690, 237893, 26549, 237536, 34313, 236900, 44068, 19966, 210921, 236951, 240588, 237653, 19966, 11034, 236951, 105832, 19966, 57489, 54971, 236924, 107, 236778, 236761, 5213, 240564, 19966, 81582, 237184, 1018, 236743, 238780, 237522, 238003, 240564, 19966, 237369, 74517, 81582, 236900, 146132, 17856, 236743, 239524, 43820, 237893, 236924, 107, 236800, 236761, 5213, 78204, 81582, 237184, 1018, 236743, 47972, 238003, 78204, 17161, 81582, 236900, 238953, 237075, 185992, 27654, 237103, 105832, 62734, 236924, 108, 1018, 241127, 237629, 69954, 237184, 1018, 108, 206402, 143206, 239301, 17856, 236743, 202504, 236743, 236778, 900, 236743, 236778, 237184, 108, 2717, 6719, 107, 3709, 578, 236743, 236778, 900, 236743, 236778, 107, 1995, 236769, 3709, 236768, 138, 236865, 236743, 185992, 236787, 236743, 236812, 107, 2717, 108, 237745, 238186, 47972, 240897, 240564, 162055, 238780, 237522, 236900, 238010, 238003, 202504, 236743, 236778, 900, 236743, 236778, 10363, 27654, 236900, 238953, 239079, 27654, 185992, 237238, 243788, 239510, 237152, 236924, 108, 1018, 173229, 237184, 1018, 108, 236829, 5213, 238780, 237522, 237026, 237193, 174322, 61883, 237184, 1018, 43758, 5157, 82092, 5938, 105850, 238780, 237522, 236900, 48982, 37502, 240564, 47972, 240897, 236924, 107, 236829, 5213, 238780, 237522, 5157, 38313, 209458, 237184, 1018, 236743, 95714, 62588, 41368, 236900, 239301, 238780, 237522, 14103, 10042, 26549, 236924, 107, 236829, 5213, 238780, 237522, 5157, 185992, 27654, 237184, 1018, 236743, 238780, 237522, 238003, 238061, 27654, 105832, 62734, 236900, 239301, 111748, 237894, 236924, 108, 1018, 240018, 238331, 237184, 1018, 236743, 238780, 237522, 55326, 237026, 47972, 240897, 236918, 237374, 237369, 193442, 48311, 78204, 60009, 152807, 236900, 239301, 47972, 237230, 19843, 67925, 236924, 108, 21226, 17161, 185411, 237230, 215620, 29666, 17856, 10363, 238780, 237522, 114071, 237354, 107], 'total_duration': 4559570300, 'load_duration': 2001830300, 'prompt_eval_count': 21, 'prompt_eval_duration': 375403800, 'eval_count': 313, 'eval_duration': 2180022400}
# 想像一下 Python 的函式就像是**工具箱**，裡面有各種各樣的工具，你可以用它們來做不同的事情。
#
# **簡單來說，Python 的函式就是：**
#
# 1. **定義一個任務：** 你想做什麼？例如，計算一個數字、讀取一個文件、顯示一個文本等等。
# 2. **寫一個指令：** 函式會寫一個小小的指令，告訴 Python 該怎麼做。
# 3. **執行指令：** 程式會執行這個指令，並在輸出結果中顯示出來。
#
# **舉個例子：**
#
# 假設你想讓 Python 算出 2 + 2：
#
# ```python
# result = 2 + 2
# print(result)  # 輸出: 4
# ```
#
# 這段程式碼寫了一個函式，它會算出 2 + 2 的結果，並將結果輸出到螢幕上。
#
# **重點：**
#
# * **函式是可重複使用的：** 你可以多次使用相同的函式，不用重新寫程式碼。
# * **函式可以接受參數：** 像是輸入資料，讓函式知道需要什麼。
# * **函式可以輸出結果：** 函式會把結果顯示出來，讓你看見。
#
# **總結：** 函式就像是程式碼的「小片段」，執行特定任務，讓程式能完成目標。
#
# 希望這個解釋能讓你理解 Python 的函式是什麼！

# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T07:54:36.8063154Z', 'response': '{ \n    "解釋：":\n    "Python 的函式就像是小程式，它們可以做特定任務，比如計算、處理資料、或是顯示訊息。 就像你用手可以做很多事情，Python 的函式也一樣，但它們在程式中運作，讓程式更聰明。"\n    \n    \n    \n    \n    \n    \n    \n}', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 239230, 237105, 74624, 48280, 185411, 26549, 237026, 32651, 236918, 238780, 237522, 237536, 106, 107, 105, 4368, 107, 236782, 236743, 107, 140, 236775, 185411, 237184, 1083, 107, 140, 236775, 32651, 10363, 238780, 237522, 55326, 237026, 237369, 47972, 236900, 162576, 5157, 237893, 60009, 152807, 236900, 30546, 44068, 236951, 93521, 41368, 236951, 67375, 105832, 203984, 236924, 236743, 55326, 237408, 237105, 237463, 5157, 237893, 15873, 25606, 236900, 32651, 10363, 238780, 237522, 237349, 59246, 236900, 237678, 162576, 237075, 47972, 237103, 238670, 237284, 236900, 239301, 47972, 237611, 244620, 237579, 165220, 107, 140, 107, 140, 107, 140, 107, 140, 107, 140, 107, 140, 107, 140, 107, 236783], 'total_duration': 2681551200, 'load_duration': 227946100, 'prompt_eval_count': 21, 'prompt_eval_duration': 103376700, 'eval_count': 85, 'eval_duration': 2077490700}
# {
#     "解釋：":
#     "Python 的函式就像是小程式，它們可以做特定任務，比如計算、處理資料、或是顯示訊息。 就像你用手可以做很多事情，Python 的函式也一樣，但它們在程式中運作，讓程式更聰明。"
#
#
#
#
#
#
#
# }
